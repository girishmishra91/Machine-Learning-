# %%
import numpy as np

# %% [markdown]
# # Indexing & Slicing with List

# %%
lst=[1,2,3,4,5,6,7,8]
print(lst[0])
# Out:
# 1

# %%
lst[2:5]
# Out:
# [3, 4, 5]

# %%
lst[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst[::2]
# Out:
# [1, 3, 5, 7]

# %%
lst[1::2]
# Out:
# [2, 4, 6, 8]

# %%
lst[2:4]=[500,1000]
lst
# Out:
# [1, 2, 500, 1000, 5, 6, 7, 8]

# %% [markdown]
# ## Indexing & Slicing with List

# %%
arr=np.array([11,12,13,14,15])
arr
# Out:
# array([11, 12, 13, 14, 15])

# %%
arr[3]=67
arr
# Out:
# array([11, 12, 13, 67, 15])

# %%
arr[-1]
# Out:
# np.int64(15)

# %%
arr[1:-1:2]
# Out:
# array([12, 67])

# %%
arr=np.delete(arr,1)
arr
# Out:
# array([11, 13, 67, 15])

# %%
lst.append(500)
lst
# Out:
# [1, 2, 500, 1000, 5, 6, 7, 8, 500]

# %%
arr=np.insert(arr,1,1000)
arr
# Out:
# array([  11, 1000,  100,   13,   67,   15])

# %%
arr[-1:1:1]
arr
# Out:
# array([  11, 1000,  100,   13,   67,   15])
